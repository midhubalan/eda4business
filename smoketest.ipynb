# %% [markdown]
# # Smoke Test

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import plotly.express as px

# %%
df = pd.DataFrame({"Yes": [20, 121], "No": [131, 2]})
df
# Out:
#    Yes   No
# 0   20  131
# 1  121    2

# %% [markdown]
# ## Demo Jupyter Native UI

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Tip:</b> Use blue boxes (alert-info) for tips and notes.
# If it’s a note, you don’t have to include the word “Note”.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Example:</b> Use yellow boxes for examples that are not
# inside code cells, or use for mathematical formulas if needed.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Up to you:</b> Use green boxes sparingly, and only for some specific
# purpose that the other boxes can't cover. For example, if you have a lot
# of related content to link to, maybe you decide to use green boxes for
# related links from each section of a notebook.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Just don't:</b> In general, avoid the red boxes. These should only be
# used for actions that might cause data loss or another major issue.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Tip:</b> Use blue boxes (alert-info) for tips and notes.
# If it’s a note, you don’t have to include the word “Note”.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Example:</b> Use yellow boxes for examples that are not
# inside code cells, or use for mathematical formulas if needed.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Up to you:</b> Use green boxes sparingly, and only for some specific
# purpose that the other boxes can't cover. For example, if you have a lot
# of related content to link to, maybe you decide to use green boxes for
# related links from each section of a notebook.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Just don't:</b> In general, avoid the red boxes. These should only be
# used for actions that might cause data loss or another major issue.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Tip:</b> Use blue boxes (alert-info) for tips and notes.
# If it’s a note, you don’t have to include the word “Note”.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Example:</b> Use yellow boxes for examples that are not
# inside code cells, or use for mathematical formulas if needed.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Up to you:</b> Use green boxes sparingly, and only for some specific
# purpose that the other boxes can't cover. For example, if you have a lot
# of related content to link to, maybe you decide to use green boxes for
# related links from each section of a notebook.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Just don't:</b> In general, avoid the red boxes. These should only be
# used for actions that might cause data loss or another major issue.
# </div>

# %% [markdown]
# ## Demo Unicode Shapes

# %% [markdown]
# <div>
#     <p>try shapes &#9632</p>
#     <p>I will display &#129033;</p>
#     <p>I will display &#x1F809;</p>
# </div>
#
# [Imports](#Imports)
#
# [UI Demo](#Demo-Jupyter-Native-UI)
#
# __[Strategic Management Course Site](https://businesspolicy.github.io/)__

# %% [markdown]
# <img src=“attachment:assets/cover-image.jpeg” alt=“Alt text” title=“Title text” />

# %% [markdown]
# <img src="attachment:ecbaefa2-36fc-4298-8988-2b479330ef64.jpeg" alt="Data Programming" title="Data Programming" width=400/>

# %% [markdown]
# ***
